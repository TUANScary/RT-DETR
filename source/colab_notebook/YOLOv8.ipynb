# %%
# !nvidia-smi
# Out:
# Wed Feb 19 15:14:54 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !wget -O /content/data.zip https://universe.roboflow.com/ds/eVwE431vTI?key=baYx9q1lTS
# Out:
# --2025-02-19 15:14:58--  https://universe.roboflow.com/ds/eVwE431vTI?key=baYx9q1lTS
# Resolving universe.roboflow.com (universe.roboflow.com)... 151.101.1.195, 151.101.65.195, 2620:0:890::100
# Connecting to universe.roboflow.com (universe.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-regional-exports/GGqN5h3Ag5Msh1nOv8tjZvWDZpv1/JEanDjT2WAirxnpcImy1/12/yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20250219%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250219T151458Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# !unzip -q /content/data.zip -d /content/custom_data

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.3/915.3 kB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# Training with 40 epoch.

# %%
# !yolo detect train data=/content/custom_data/data.yaml model=yolov8s.pt epochs=40 imgsz=480
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 21.5M/21.5M [00:00<00:00, 95.9MB/s]
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo val data=/content/custom_data/data.yaml model=runs/detect/train/weights/best.pt imgsz=480
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/custom_data/valid/labels.cache... 49 images, 0 backgrounds, 0 corrupt: 100% 49/49 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.15it/s]
#                    all         49       1174      0.902      0.613      0.693      0.436
#                   ball         45         45          1     0.0863      0.113     0.0168
#             goalkeeper         38         39        0.9      0.692      0.877      0.542
#                 player         49        973      0.904      0.904      0.951      0.682
#                referee         49        117      0.803      0.769      0.829      0.506
# Speed: 7.2ms preprocess, 9.9ms inference, 0.0ms loss, 8.0ms postprocess per image
# Results saved to runs/detect/val
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt source=/content/custom_data/valid/images save=True
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/49 /content/custom_data/valid/images/08fd33_3_1_png.rf.894a7edd6b726ed886b3777ea55d6beb.jpg: 480x480 18 players, 2 referees, 11.7ms
# image 2/49 /content/custom_data/valid/images/08fd33_3_3_png.rf.7aaf5d38e77c064882cb7b0f80e7e156.jpg: 480x480 20 players, 2 referees, 11.3ms
# image 3/49 /content/custom_data/valid/images/08fd33_9_8_png.rf.c4792b7740c5e581674385c8a2c149fe.jpg: 480x480 22 players, 2 referees, 10.7ms
# image 4/49 /content/custom_data/valid/images/121364_7_9_png.rf.0b474ed35ea4cab1acb2fc14ef64c7cc.jpg: 480x480 17 players, 1 referee, 10.7ms
# image 5/49 /content/custom_data/valid/images/121364_9_2_png.rf.4028ff624f963fe501d9bf2b563582ca.jpg: 480x480 1 goalkeeper, 22 players, 2 referees, 10.9ms
# ...

# %% [markdown]
# Training with 100 epoch

# %%
# !yolo detect train data=/content/custom_data/data.yaml model=yolov8s.pt epochs=100 imgsz=480
# Out:
# Ultralytics 8.3.77 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo val data=/content/custom_data/data.yaml model=/content/runs/detect/train2/weights/best.pt imgsz=480
# Out:
# Ultralytics 8.3.77 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/custom_data/valid/labels.cache... 49 images, 0 backgrounds, 0 corrupt: 100% 49/49 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.11it/s]
#                    all         49       1174      0.851      0.663      0.744      0.482
#                   ball         45         45      0.776     0.0784      0.241     0.0623
#             goalkeeper         38         39      0.843      0.825      0.889       0.59
#                 player         49        973      0.937      0.912      0.964      0.707
#                referee         49        117      0.848      0.838      0.883      0.569
# Speed: 7.2ms preprocess, 19.2ms inference, 0.0ms loss, 8.2ms postprocess per image
# Results saved to runs/detect/val
# ...
